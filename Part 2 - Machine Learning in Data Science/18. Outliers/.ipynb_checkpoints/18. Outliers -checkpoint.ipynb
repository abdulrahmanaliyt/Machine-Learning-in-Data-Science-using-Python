# %% [markdown]
# # Outliers

# %% [markdown]
# ## Dataset Used: solid_waste_generation_recycling

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\HP\A  Self Pace ML\18. Outliers\solid_waste_generation_recycling.csv")

# %%
data.head()
# Out:
#    Year  Agricultural Organic Waste  Aluminum Cans  Anti-freeze  \
# 0  2000                           0          17944         2475
# 1  2001                           0          12540         4157
# 2  2002                           0          12718         4506
# 3  2003                           0          17608         4722
# 4  2004                           0          16010         8050
#
#    Appliances/White Goods  Ash, Sand & Dust used  Asphalt/Concrete  Batteries  \
# 0                   35427                  10000            893218      25795
# 1                   39180                  12333           1116871      10860
# 2                   43833                    290           1451959      15390
# 3                   53353                  10576           1600288      21964
# 4                   56920                  40409           2002171      21284
#
#    Cardboard  Glass  ...  Other_Waste_Type_49  Other_Waste_Type_50  \
# ...

# %%
data.shape
# Out:
# (15, 80)

# %%
data.columns
# Out:
# Index(['Year', 'Agricultural Organic Waste', 'Aluminum Cans', 'Anti-freeze',
#        'Appliances/White Goods', 'Ash, Sand & Dust used', 'Asphalt/Concrete',
#        'Batteries', 'Cardboard', 'Glass', 'Paper', 'Plastics', 'Textiles',
#        'Wood', 'Rubber', 'Leather', 'Yard Trimmings', 'Food Waste',
#        'Electronics', 'Metals', 'Demolition Debris', 'Hazardous Waste',
#        'Other_Waste_Type_1', 'Other_Waste_Type_2', 'Other_Waste_Type_3',
#        'Other_Waste_Type_4', 'Other_Waste_Type_5', 'Other_Waste_Type_6',
#        'Other_Waste_Type_7', 'Other_Waste_Type_8', 'Other_Waste_Type_9',
#        'Other_Waste_Type_10', 'Other_Waste_Type_11', 'Other_Waste_Type_12',
#        'Other_Waste_Type_13', 'Other_Waste_Type_14', 'Other_Waste_Type_15',
#        'Other_Waste_Type_16', 'Other_Waste_Type_17', 'Other_Waste_Type_18',
#        'Other_Waste_Type_19', 'Other_Waste_Type_20', 'Other_Waste_Type_21',
#        'Other_Waste_Type_22', 'Other_Waste_Type_23', 'Other_Waste_Type_24',
# ...

# %%
data.isna().sum()
# Out:
# Year                          0
# Agricultural Organic Waste    0
# Aluminum Cans                 0
# Anti-freeze                   0
# Appliances/White Goods        0
#                              ..
# Other_Waste_Type_54           0
# Other_Waste_Type_55           0
# Other_Waste_Type_56           0
# Other_Waste_Type_57           0
# Other_Waste_Type_58           0
# Length: 80, dtype: int64

# %%
# Sort the dataframe by the target column
df=df_sorted = data.sort_values('Aluminum Cans')

# %%
# 1. Check for unusually low outliers (Smallest values)
print("--- 5 Smallest Values ---")
print(df_sorted[['Year', 'Aluminum Cans']].head())
# Out:
# --- 5 Smallest Values ---
#     Year  Aluminum Cans
# 1   2001          12540
# 2   2002          12718
# 8   2008          12842
# 11  2011          13115
# 12  2012          13635

# %%
# 2. Check for unusually high outliers (Largest values)
print("\n--- 5 Largest Values ---")
print(df_sorted[['Year', 'Aluminum Cans']].tail())
# Out:
# --- 5 Largest Values ---
#     Year  Aluminum Cans
# 4   2004          16010
# 13  2013          16679
# 3   2003          17608
# 0   2000          17944
# 9   2009          21098

# %% [markdown]
# # Drawing Graphs / Plots

# %%
import seaborn as sns

# %%
sns.boxenplot(data=data, x='Aluminum Cans')
# Out:
# <Axes: xlabel='Aluminum Cans'>

# %%
sns.displot(data=data, x='Aluminum Cans', bins = 10)

# %% [markdown]
# # Inter  Quartile Range (IQR) Method

# %%
# 1. Calculate Quartiles and IQR for 'Aluminum Cans'
Q1 = data['Aluminum Cans'].quantile(0.25)
Q3 = data['Aluminum Cans'].quantile(0.75)
IQR = Q3 - Q1

# %%
IQR
# Out:
# np.float64(2969.5)

# %%
# 2. Define upper and lower bounds
ll = lower_bound = Q1 - 1.5 * IQR
ul = upper_bound = Q3 + 1.5 * IQR

# %%
print('Lower Limit',lower_bound,'\nUpper Limit', upper_bound)
# Out:
# Lower Limit 8920.75
# Upper Limit 20798.75

# %%
# 3. Filter out the outliers
outliers_iqr = data[(data['Aluminum Cans'] < lower_bound) | (data['Aluminum Cans'] > upper_bound)]
clean_data_iqr = data[(data['Aluminum Cans'] >= lower_bound) & (data['Aluminum Cans'] <= upper_bound)]

print(f"Number of outliers detected via IQR: {len(outliers_iqr)}")
# Out:
# Number of outliers detected via IQR: 1

# %%
# Make sure each condition is fully enclosed in parentheses () 
# and the syntax for both sides is complete.
data[(data['Aluminum Cans'] <= lower_bound) | (data['Aluminum Cans'] >= upper_bound)]['Aluminum Cans']
# Out:
# 9    21098
# Name: Aluminum Cans, dtype: int64

# %% [markdown]
# # How to Handle Outliers

# %%
import numpy as np
np.where(data['Aluminum Cans'] <= lower_bound)
# Out:
# (array([], dtype=int64),)

# %%
np.where(data['Aluminum Cans'] >= upper_bound)
# Out:
# (array([9]),)

# %%
data['Aluminum Cans'][9]
# Out:
# np.int64(21098)

# %%
ll
# Out:
# np.float64(8920.75)

# %%
ul
# Out:
# np.float64(20798.75)

# %%
data['Aluminum Cans'].values
# Out:
# array([17944, 12540, 12718, 17608, 16010, 15441, 14951, 14005, 12842,
#        21098, 13655, 13115, 13635, 16679, 14309])

# %%
arr = data['Aluminum Cans'].values

# %%
true_index = (ll < arr ) & (arr < ul )

# %%
true_index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True])

# %%
mid = np.median(data['Aluminum Cans'][true_index])

# %%
mid
# Out:
# np.float64(14157.0)

# %%
false_index = ~true_index

# %%
data['Aluminum Cans'].values[false_index] = mid

# %%
def highlight_cell(x):
    # Create a DataFrame of empty styles with the same shape as your data
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    # Set the background color for your specific row index and column name
    df_styler.at[9, 'Aluminum Cans'] = 'background-color: yellow; color: black; font-weight: bold'
    return df_styler

# Apply the style and display the DataFrame
data.style.apply(highlight_cell, axis=None)
# Out:
# <style type="text/css">
# #T_7a76e_row9_col2 {
#   background-color: yellow;
#   color: black;
#   font-weight: bold;
# }
# </style>
# <table id="T_7a76e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a76e_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_7a76e_level0_col1" class="col_heading level0 col1" >Agricultural Organic Waste</th>
#       <th id="T_7a76e_level0_col2" class="col_heading level0 col2" >Aluminum Cans</th>
#       <th id="T_7a76e_level0_col3" class="col_heading level0 col3" >Anti-freeze</th>
#       <th id="T_7a76e_level0_col4" class="col_heading level0 col4" >Appliances/White Goods</th>
#       <th id="T_7a76e_level0_col5" class="col_heading level0 col5" >Ash, Sand & Dust used</th>
#       <th id="T_7a76e_level0_col6" class="col_heading level0 col6" >Asphalt/Concrete</th>
#       <th id="T_7a76e_level0_col7" class="col_heading level0 col7" >Batteries</th>
# ...

# %%
# checking for ouliers

def highlight_outliers(val):
    if val >= upper_bound or val <= lower_bound:
        return 'background-color: yellow; color: black; font-weight: bold;'
    return ''

# By adding [['Year', 'Aluminum Cans']], we filter out the other 50+ columns 
# so the styling renders perfectly on your screen!
data[['Year', 'Aluminum Cans']].style.map(highlight_outliers, subset=['Aluminum Cans'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_c38ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c38ae_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_c38ae_level0_col1" class="col_heading level0 col1" >Aluminum Cans</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c38ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c38ae_row0_col0" class="data row0 col0" >2000</td>
#       <td id="T_c38ae_row0_col1" class="data row0 col1" >17944</td>
#     </tr>
#     <tr>
#       <th id="T_c38ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c38ae_row1_col0" class="data row1 col0" >2001</td>
#       <td id="T_c38ae_row1_col1" class="data row1 col1" >12540</td>
#     </tr>
#     <tr>
#       <th id="T_c38ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c38ae_row2_col0" class="data row2 col0" >2002</td>
# ...

# %%
data
# Out:
#     Year  Agricultural Organic Waste  Aluminum Cans  Anti-freeze  \
# 0   2000                           0          17944         2475
# 1   2001                           0          12540         4157
# 2   2002                           0          12718         4506
# 3   2003                           0          17608         4722
# 4   2004                           0          16010         8050
# 5   2005                           0          15441         8767
# 6   2006                           0          14951         7507
# 7   2007                           0          14005         7055
# 8   2008                       31800          12842         6586
# 9   2009                       45431          14157         5194
# 10  2010                       55689          13655         4783
# 11  2011                       76645          13115         4872
# 12  2012                      102732          13635         6797
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Agricultural Organic Waste', 'Aluminum Cans', 'Anti-freeze',
#        'Appliances/White Goods', 'Ash, Sand & Dust used', 'Asphalt/Concrete',
#        'Batteries', 'Cardboard', 'Glass', 'Paper', 'Plastics', 'Textiles',
#        'Wood', 'Rubber', 'Leather', 'Yard Trimmings', 'Food Waste',
#        'Electronics', 'Metals', 'Demolition Debris', 'Hazardous Waste',
#        'Other_Waste_Type_1', 'Other_Waste_Type_2', 'Other_Waste_Type_3',
#        'Other_Waste_Type_4', 'Other_Waste_Type_5', 'Other_Waste_Type_6',
#        'Other_Waste_Type_7', 'Other_Waste_Type_8', 'Other_Waste_Type_9',
#        'Other_Waste_Type_10', 'Other_Waste_Type_11', 'Other_Waste_Type_12',
#        'Other_Waste_Type_13', 'Other_Waste_Type_14', 'Other_Waste_Type_15',
#        'Other_Waste_Type_16', 'Other_Waste_Type_17', 'Other_Waste_Type_18',
#        'Other_Waste_Type_19', 'Other_Waste_Type_20', 'Other_Waste_Type_21',
#        'Other_Waste_Type_22', 'Other_Waste_Type_23', 'Other_Waste_Type_24',
# ...

# %% [markdown]
# # Program 2

# %%
# outliers dection and handling in 'Ash, Sand & Dust used' in 'Asphalt/Concrete' productionabs
import numpy as np 
import pandas as pd 
import seaborn as sns
d2 = pd.read_csv(r"C:\Users\HP\A  Self Pace ML\18. Outliers\solid_waste_generation_recycling.csv")
# no of rows and columns
d2.shape
# Out:
# (15, 80)

# %%
# rename the column: 'Ash, Sand & Dust used' 
# Production as target column
# pass distionary with old name and new name 
d2.rename(columns={'Ash, Sand & Dust used': 'Target'}, inplace=True)

# %%
# let us find outliers , sort on target column
df1 = d2.sort_values('Target')

df1['Target'].head()

df1['Target'].tail()
# Out:
# 3     10576
# 1     12333
# 5     14588
# 10    20364
# 4     40409
# Name: Target, dtype: int64

# %%
df1[df1['Target'] == 40409].index
df1.index[-1]
# Out:
# np.int64(4)

# %%
# display the all rows of target column (this is the 5th column)
# 0s cannot be outliers but the last row is 40409 this is outliers
df.iloc[:,5]
# Out:
# 1     12333
# 2       290
# 8         0
# 11        0
# 12        0
# 10    20364
# 7      2521
# 14        0
# 6      4008
# 5     14588
# 4     40409
# 13        0
# 3     10576
# 0     10000
# 9       344
# Name: Ash, Sand & Dust used, dtype: int64

# %%
# let us find outliers bt drawing graphs / plots
# from the below plot, the outlires is after 40000 
sns.boxplot(data=d2 , x = 'Target')
# Out:
# <Axes: xlabel='Target'>

# %%
sns.displot(data= d2,x='Target', bins = 20)

# %%
# calculate IQR
q3 = d2['Target'].quantile(.75) 
q1 = d2['Target'].quantile(.25)

# %%
print('q1',q1)
print('q3',q3)

# Find IQR 
iqr = q3 - q1
iqr
# Out:
# q1 0.0
# q3 11454.5
# np.float64(11454.5)

# %%
# calculate upper and lower limit
ul = q3 +(1.5*iqr)
ll = q1 -(1.5*iqr)
print(ul,ll)
# Out:
# 28636.25 -17181.75

# %%
def highlight_target_outliers(val):
    # Use limits (28636.25 and 17181.75)
    if val >= ul or val <= ll:
        return 'background-color: yellow; color: black; font-weight: bold;'
    return ''

# %%
df1[['Year', 'Target']].style.map(highlight_target_outliers, subset=['Target'])
# Out:
# <style type="text/css">
# #T_1bce7_row14_col1 {
#   background-color: yellow;
#   color: black;
#   font-weight: bold;
# }
# </style>
# <table id="T_1bce7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bce7_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_1bce7_level0_col1" class="col_heading level0 col1" >Target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bce7_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_1bce7_row0_col0" class="data row0 col0" >2008</td>
#       <td id="T_1bce7_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1bce7_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_1bce7_row1_col0" class="data row1 col0" >2011</td>
#       <td id="T_1bce7_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1bce7_level0_row2" class="row_heading level0 row2" >12</th>
# ...

# %%
upper = np.where(d2['Target']>=ul)
lower = np.where(d2['Target']<=ll)

# %%
# delete the rows above upper and below lower values 
d2.drop(upper[0], inplace=True) 
d2.drop(lower[0], inplace=True)

# %%
# if arr values are in between ll and ul , represent that 
# calue as True else as False 
# False values are outliers - we can find it at 5th position 
arr = df1['Target'].values
true_index = (ll < arr) & (arr < ul)
true_index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False])

# %%
# let us substutute mean value inthe place of outliers
# so calculate mean of all values other than the outliers. 
# 1. Calculate the mean ('mid') using ONLY the valid non-outlier rows from df1
mid = df1.loc[true_index, 'Target'].mean()
mid
# Out:
# np.float64(5358.857142857143)

# %%
# 2. Create the false_index mask to isolate ONLY the outlier rows
false_index = ~true_index

# %%
# 3. Replace ONLY the outliers in df1 with that clean mean value
df1['Target'].values[false_index] = mid

# %%
# 4. View your updated dataframe
df1['Target']
# Out:
# 8         0
# 11        0
# 12        0
# 13        0
# 14        0
# 2       290
# 9       344
# 7      2521
# 6      4008
# 0     10000
# 3     10576
# 1     12333
# 5     14588
# 10    20364
# 4      5358
# Name: Target, dtype: int64

# %%
def highlight_target_outliers(val):
    # Use limits (28636.25 and 17181.75)
    if val >= ul or val <= ll:
        return 'background-color: yellow; color: black; font-weight: bold;'
    return ''

df1[['Year', 'Target']].style.map(highlight_target_outliers, subset=['Target'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_36190">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36190_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_36190_level0_col1" class="col_heading level0 col1" >Target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36190_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_36190_row0_col0" class="data row0 col0" >2008</td>
#       <td id="T_36190_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_36190_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_36190_row1_col0" class="data row1 col0" >2011</td>
#       <td id="T_36190_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_36190_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_36190_row2_col0" class="data row2 col0" >2012</td>
# ...

# %%
def highlight_cell(x):
    # Create a DataFrame of empty styles with the same shape as your data
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    # Set the background color for your specific row index and column name
    df_styler.at[5, 'Target'] = 'background-color: yellow; color: black; font-weight: bold'
    return df_styler

df1.style.apply(highlight_cell, axis=None)
# Out:
# <style type="text/css">
# #T_c16c5_row12_col5 {
#   background-color: yellow;
#   color: black;
#   font-weight: bold;
# }
# </style>
# <table id="T_c16c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c16c5_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_c16c5_level0_col1" class="col_heading level0 col1" >Agricultural Organic Waste</th>
#       <th id="T_c16c5_level0_col2" class="col_heading level0 col2" >Aluminum Cans</th>
#       <th id="T_c16c5_level0_col3" class="col_heading level0 col3" >Anti-freeze</th>
#       <th id="T_c16c5_level0_col4" class="col_heading level0 col4" >Appliances/White Goods</th>
#       <th id="T_c16c5_level0_col5" class="col_heading level0 col5" >Target</th>
#       <th id="T_c16c5_level0_col6" class="col_heading level0 col6" >Asphalt/Concrete</th>
#       <th id="T_c16c5_level0_col7" class="col_heading level0 col7" >Batteries</th>
# ...

# %%
sns.displot(data=d2, x= 'Target', bins = 15)

# %%
df1['Target']
# Out:
# 8         0
# 11        0
# 12        0
# 13        0
# 14        0
# 2       290
# 9       344
# 7      2521
# 6      4008
# 0     10000
# 3     10576
# 1     12333
# 5     14588
# 10    20364
# 4      5358
# Name: Target, dtype: int64
